# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.47M/1.47M [00:00<00:00, 3.31MB/s]
# Extracting files...
# Path to dataset files: /Users/amitchoubey/.cache/kagglehub/datasets/dylanjcastillo/7k-books-with-metadata/versions/3

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv(f"{path}/books.csv")
books.head(3)
# Out:
#           isbn13      isbn10         title subtitle  \
# 0  9780002005883  0002005883        Gilead      NaN
# 1  9780002261982  0002261987  Spider's Web  A Novel
# 2  9780006163831  0006163831  The One Tree      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# ...

# %%
books.columns
# Out:
# Index(['isbn13', 'isbn10', 'title', 'subtitle', 'authors', 'categories',
#        'thumbnail', 'description', 'published_year', 'average_rating',
#        'num_pages', 'ratings_count', 'description_missing'],
#       dtype='object')

# %% [markdown]
# Important field such as description author title and so on

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   thumbnail       6481 non-null   object
#  7   description     6548 non-null   object
#  8   published_year  6804 non-null   float64
#  9   average_rating  6767 non-null   float64
#  10  num_pages       6767 non-null   float64
#  11  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 638.6+ KB

# %%
books.describe()
# Out:
#              isbn13  published_year  average_rating    num_pages  \
# count  6.810000e+03     6804.000000     6767.000000  6767.000000
# mean   9.780677e+12     1998.630364        3.933284   348.181026
# std    6.068911e+08       10.484257        0.331352   242.376783
# min    9.780002e+12     1853.000000        0.000000     0.000000
# 25%    9.780330e+12     1996.000000        3.770000   208.000000
# 50%    9.780553e+12     2002.000000        3.960000   304.000000
# 75%    9.780810e+12     2005.000000        4.130000   420.000000
# max    9.789042e+12     2019.000000        5.000000  3342.000000
#
#        ratings_count
# count   6.767000e+03
# mean    2.106910e+04
# std     1.376207e+05
# min     0.000000e+00
# 25%     1.590000e+02
# 50%     1.018000e+03
# 75%     5.992500e+03
# max     5.629932e+06

# %%
books.isna().sum()
# Out:
# isbn13               0
# isbn10               0
# title                0
# subtitle          4429
# authors             72
# categories          99
# thumbnail          329
# description        262
# published_year       6
# average_rating      43
# num_pages           43
# ratings_count       43
# dtype: int64

# %%
books["categories"].value_counts
# Important field such as description author title and so on
# Out:
# <bound method IndexOpsMixin.value_counts of 0                             Fiction
# 1       Detective and mystery stories
# 2                    American fiction
# 3                             Fiction
# 4                      Christian life
#                     ...
# 6805                       Philosophy
# 6806                        Mysticism
# 6807                     Book burning
# 6808                          History
# 6809               Literary Criticism
# Name: categories, Length: 6810, dtype: object>

# %%
ax = plt.axes()
trans = books.isna().transpose()
sns.heatmap(trans, cbar=False, ax=ax)

plt.xlabel("feature")
plt.ylabel("Missing values")

plt.title("Missing values in books dataset")
plt.show()

# %%
books["description_missing"] = books["description"].isna()
books["description_missing"].value_counts()
# Out:
# description_missing
# False    6548
# True      262
# Name: count, dtype: int64

# %%
books["description_missing"] = np.where(books["description"].isna(), 1,0)

# %%
col_for_corr = ["num_pages", "description_missing", "average_rating"]
correlation_matrix = books[["num_pages", "description_missing", "average_rating"]].corr(method="spearman")

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
book_missing = books.dropna(subset=["description", "num_pages", "average_rating", "published_year"])
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   isbn13               6810 non-null   int64
#  1   isbn10               6810 non-null   object
#  2   title                6810 non-null   object
#  3   subtitle             2381 non-null   object
#  4   authors              6738 non-null   object
#  5   categories           6711 non-null   object
#  6   thumbnail            6481 non-null   object
#  7   description          6548 non-null   object
#  8   published_year       6804 non-null   float64
#  9   average_rating       6767 non-null   float64
#  10  num_pages            6767 non-null   float64
#  11  ratings_count        6767 non-null   float64
#  12  description_missing  6810 non-null   int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 691.8+ KB

# %%
top_categories = book_missing["categories"].value_counts().reset_index().sort_values("count",ascending=False)
top_categories
# Out:
#                     categories  count
# 0                      Fiction   2523
# 1             Juvenile Fiction    534
# 2    Biography & Autobiography    391
# 3                      History    258
# 4           Literary Criticism    164
# ..                         ...    ...
# 280                    Butlers      1
# 279                    Gardens      1
# 278                  Assassins      1
# 277             Married people      1
# 530    Indic fiction (English)      1
#
# [531 rows x 2 columns]

# %%
# plt.figure(figsize=(10, 6))
# ax = sns.barplot(data=top_categories, x="category", y="count", palette="viridis")
# plt.xlabel("Category")
# plt.ylabel("Count")
# plt.title("Top 10 Book Categories")
# plt.xticks(rotation=30, ha='right')
# plt.tight_layout()
# plt.show()
